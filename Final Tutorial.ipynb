# %% [markdown]
# # Analysis of Montgomery County Police Incident Dispatch
#    #### (Marc Kemgang)

# %% [markdown]
# ## Introduction:
#
# The goal of this tutorial is to analyze Montgomery County Police Dispatched Incindent data from the year 2019 to 2022 and inform Montgomery Conuty residents the most common type of crime that happen in their city. Such information is important because
#
# Throghout this tutorial, I'll try to find trends between the types of crimes, the city in which the crime took place and also how they correlate with police response time to determine which city is the "safest".

# %% [markdown]
# ## Required Tools
# This tutorial use Python 3 as well as the following imported libraries.

# %%
# Necessary libraries and imports to complete this tutorial
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
import seaborn as sns
from sklearn import model_selection
from sklearn import linear_model
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
import statsmodels.formula.api as smf

# %% [markdown]
# ## 1. Data Collection
#
# This is the first stage in the data pipeline. The [data](https://data.montgomerycountymd.gov/Public-Safety/Police-Dispatched-Incidents/98cc-bc7d) is a Montgomery County dataset which contains a list of police dispatched indidents records from 2019 to today. It's updated daily and has over a million rows.

# %% [markdown]
# ### Reading the data

# %%
dispatch_table = pd.read_csv("Police_Dispatched_Incidents.csv")
dispatch_table.head()
# Out:
#    Incident_ID Crime Reports Crash Reports              Start Time  \
# 0  P1900099420     190014036           NaN  03/26/2019 07:37:19 PM
# 1  P1900281711     190040608           NaN  08/25/2019 01:01:36 AM
# 2  P1900027078     190003827           NaN  01/24/2019 05:38:00 PM
# 3  P1900366994     190053313           NaN  11/05/2019 02:43:58 PM
# 4  P1900219122           NaN           NaN  07/01/2019 11:35:38 PM
#
#                  End Time  Priority                           Initial Type  \
# 0  03/26/2019 08:40:41 PM         4       THEFT/LARCENY - OCCURRED EARLIER
# 1  08/25/2019 01:49:12 AM         1         MISSING, RUNAWAY, FOUND PERSON
# 2  01/24/2019 10:41:53 PM         3  INDECENCY/LEWDNESS - OCCURRED EARLIER
# 3  11/05/2019 04:56:51 PM         4     FRAUD/DECEPTION - OCCURRED EARLIER
# 4  07/01/2019 11:49:08 PM         0          DOMESTIC DISTURBANCE/VIOLENCE
#
#                               Close Type                   Address  \
# ...
